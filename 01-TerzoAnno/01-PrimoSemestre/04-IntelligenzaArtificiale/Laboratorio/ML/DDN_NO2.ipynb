# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(40, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), alla activation functions should be ReLU.

# %%
def create_model_tiny(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(3, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium(input_size):
    # create model
    model = Sequential()    
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matring among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() #n_df=n_df.values

#divide predictors from features
X = n_df[:, 1:]; # All features (cols from 2 to 8)
y = n_df[:, 0]; # Only predictors (col 1)

print("df shape ", n_df.shape)
print("X shape ", X.shape)
print("y shape ", y.shape)

seed = 7
np.random.seed(seed)

# split dataset in 77% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);#insert your code here

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_large(X_train.shape[1])
model.summary()
# Out:
# df shape  (500, 8)
# X shape  (500, 7)
# y shape  (500,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 10)                80
#
#  dense_5 (Dense)             (None, 30)                330
#
#  dense_6 (Dense)             (None, 40)                1240
#
#  dense_7 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 1,691
# Trainable params: 1,691
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 [==============================] - 2s 76ms/step - loss: 15.0218 - mean_absolute_error: 3.7989 - val_loss: 13.4297 - val_mean_absolute_error: 3.5930
# Epoch 2/150
# 9/9 [==============================] - 0s 12ms/step - loss: 12.6859 - mean_absolute_error: 3.4856 - val_loss: 11.2677 - val_mean_absolute_error: 3.2783
# Epoch 3/150
# 9/9 [==============================] - 0s 13ms/step - loss: 10.5610 - mean_absolute_error: 3.1677 - val_loss: 9.1447 - val_mean_absolute_error: 2.9340
# Epoch 4/150
# 9/9 [==============================] - 0s 13ms/step - loss: 8.4039 - mean_absolute_error: 2.8035 - val_loss: 6.8679 - val_mean_absolute_error: 2.5130
# Epoch 5/150
# 9/9 [==============================] - 0s 12ms/step - loss: 6.0842 - mean_absolute_error: 2.3498 - val_loss: 4.5056 - val_mean_absolute_error: 1.9850
# Epoch 6/150
# 9/9 [==============================] - 0s 11ms/step - loss: 3.7436 - mean_absolute_error: 1.7706 - val_loss: 2.4182 - val_mean_absolute_error: 1.3743
# Epoch 7/150
# 9/9 [==============================] - 0s 12ms/step - loss: 1.8436 - mean_absolute_error: 1.1433 - val_loss: 1.2783 - val_mean_absolute_error: 0.9045
# Epoch 8/150
# 9/9 [==============================] - 0s 11ms/step - loss: 1.0435 - mean_absolute_error: 0.7999 - val_loss: 1.1774 - val_mean_absolute_error: 0.8545
# Epoch 9/150
# 9/9 [==============================] - 0s 13ms/step - loss: 1.0113 - mean_absolute_error: 0.7820 - val_loss: 1.1212 - val_mean_absolute_error: 0.8355
# Epoch 10/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.8537 - mean_absolute_error: 0.7066 - val_loss: 0.9206 - val_mean_absolute_error: 0.7483
# Epoch 11/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7271 - mean_absolute_error: 0.6506 - val_loss: 0.8362 - val_mean_absolute_error: 0.7114
# Epoch 12/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.6563 - mean_absolute_error: 0.6226 - val_loss: 0.7698 - val_mean_absolute_error: 0.6836
# Epoch 13/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.5911 - mean_absolute_error: 0.5895 - val_loss: 0.7086 - val_mean_absolute_error: 0.6563
# Epoch 14/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.5479 - mean_absolute_error: 0.5639 - val_loss: 0.6561 - val_mean_absolute_error: 0.6338
# Epoch 15/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.5118 - mean_absolute_error: 0.5465 - val_loss: 0.6112 - val_mean_absolute_error: 0.6120
# Epoch 16/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4804 - mean_absolute_error: 0.5285 - val_loss: 0.5893 - val_mean_absolute_error: 0.5975
# Epoch 17/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4583 - mean_absolute_error: 0.5192 - val_loss: 0.5517 - val_mean_absolute_error: 0.5839
# Epoch 18/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4342 - mean_absolute_error: 0.5074 - val_loss: 0.5315 - val_mean_absolute_error: 0.5720
# Epoch 19/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4161 - mean_absolute_error: 0.4968 - val_loss: 0.5097 - val_mean_absolute_error: 0.5605
# Epoch 20/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4019 - mean_absolute_error: 0.4890 - val_loss: 0.4827 - val_mean_absolute_error: 0.5491
# Epoch 21/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3898 - mean_absolute_error: 0.4825 - val_loss: 0.4733 - val_mean_absolute_error: 0.5391
# Epoch 22/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3785 - mean_absolute_error: 0.4753 - val_loss: 0.4619 - val_mean_absolute_error: 0.5337
# Epoch 23/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3694 - mean_absolute_error: 0.4685 - val_loss: 0.4569 - val_mean_absolute_error: 0.5295
# Epoch 24/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3622 - mean_absolute_error: 0.4626 - val_loss: 0.4475 - val_mean_absolute_error: 0.5258
# Epoch 25/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3570 - mean_absolute_error: 0.4599 - val_loss: 0.4379 - val_mean_absolute_error: 0.5208
# Epoch 26/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3467 - mean_absolute_error: 0.4534 - val_loss: 0.4325 - val_mean_absolute_error: 0.5156
# Epoch 27/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3487 - mean_absolute_error: 0.4539 - val_loss: 0.4268 - val_mean_absolute_error: 0.5128
# Epoch 28/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3359 - mean_absolute_error: 0.4465 - val_loss: 0.4101 - val_mean_absolute_error: 0.5059
# Epoch 29/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3302 - mean_absolute_error: 0.4435 - val_loss: 0.4071 - val_mean_absolute_error: 0.5025
# Epoch 30/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3322 - mean_absolute_error: 0.4447 - val_loss: 0.4091 - val_mean_absolute_error: 0.5009
# Epoch 31/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3220 - mean_absolute_error: 0.4375 - val_loss: 0.3977 - val_mean_absolute_error: 0.4972
# Epoch 32/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3165 - mean_absolute_error: 0.4323 - val_loss: 0.3976 - val_mean_absolute_error: 0.4960
# Epoch 33/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3155 - mean_absolute_error: 0.4307 - val_loss: 0.3952 - val_mean_absolute_error: 0.4939
# Epoch 34/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3083 - mean_absolute_error: 0.4295 - val_loss: 0.3835 - val_mean_absolute_error: 0.4895
# Epoch 35/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3051 - mean_absolute_error: 0.4262 - val_loss: 0.3776 - val_mean_absolute_error: 0.4862
# Epoch 36/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3032 - mean_absolute_error: 0.4263 - val_loss: 0.3788 - val_mean_absolute_error: 0.4853
# Epoch 37/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2961 - mean_absolute_error: 0.4197 - val_loss: 0.3694 - val_mean_absolute_error: 0.4793
# Epoch 38/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2943 - mean_absolute_error: 0.4179 - val_loss: 0.3631 - val_mean_absolute_error: 0.4758
# Epoch 39/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2899 - mean_absolute_error: 0.4151 - val_loss: 0.3605 - val_mean_absolute_error: 0.4739
# Epoch 40/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2863 - mean_absolute_error: 0.4115 - val_loss: 0.3583 - val_mean_absolute_error: 0.4723
# Epoch 41/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2832 - mean_absolute_error: 0.4090 - val_loss: 0.3554 - val_mean_absolute_error: 0.4716
# Epoch 42/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2822 - mean_absolute_error: 0.4087 - val_loss: 0.3543 - val_mean_absolute_error: 0.4719
# Epoch 43/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2775 - mean_absolute_error: 0.4030 - val_loss: 0.3497 - val_mean_absolute_error: 0.4698
# Epoch 44/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2759 - mean_absolute_error: 0.4034 - val_loss: 0.3456 - val_mean_absolute_error: 0.4670
# Epoch 45/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2723 - mean_absolute_error: 0.4005 - val_loss: 0.3410 - val_mean_absolute_error: 0.4630
# Epoch 46/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2699 - mean_absolute_error: 0.3984 - val_loss: 0.3388 - val_mean_absolute_error: 0.4614
# Epoch 47/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2673 - mean_absolute_error: 0.3957 - val_loss: 0.3368 - val_mean_absolute_error: 0.4591
# Epoch 48/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2654 - mean_absolute_error: 0.3937 - val_loss: 0.3353 - val_mean_absolute_error: 0.4593
# Epoch 49/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2630 - mean_absolute_error: 0.3918 - val_loss: 0.3328 - val_mean_absolute_error: 0.4571
# Epoch 50/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2624 - mean_absolute_error: 0.3898 - val_loss: 0.3262 - val_mean_absolute_error: 0.4501
# Epoch 51/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2598 - mean_absolute_error: 0.3903 - val_loss: 0.3269 - val_mean_absolute_error: 0.4505
# Epoch 52/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2583 - mean_absolute_error: 0.3879 - val_loss: 0.3263 - val_mean_absolute_error: 0.4480
# Epoch 53/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2575 - mean_absolute_error: 0.3874 - val_loss: 0.3247 - val_mean_absolute_error: 0.4472
# Epoch 54/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2556 - mean_absolute_error: 0.3871 - val_loss: 0.3232 - val_mean_absolute_error: 0.4482
# Epoch 55/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2532 - mean_absolute_error: 0.3845 - val_loss: 0.3237 - val_mean_absolute_error: 0.4507
# Epoch 56/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2516 - mean_absolute_error: 0.3839 - val_loss: 0.3189 - val_mean_absolute_error: 0.4445
# Epoch 57/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2503 - mean_absolute_error: 0.3827 - val_loss: 0.3182 - val_mean_absolute_error: 0.4437
# Epoch 58/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2567 - mean_absolute_error: 0.3911 - val_loss: 0.3208 - val_mean_absolute_error: 0.4523
# Epoch 59/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2499 - mean_absolute_error: 0.3863 - val_loss: 0.3137 - val_mean_absolute_error: 0.4447
# Epoch 60/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2464 - mean_absolute_error: 0.3838 - val_loss: 0.3117 - val_mean_absolute_error: 0.4435
# Epoch 61/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2469 - mean_absolute_error: 0.3854 - val_loss: 0.3098 - val_mean_absolute_error: 0.4408
# Epoch 62/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2431 - mean_absolute_error: 0.3804 - val_loss: 0.3069 - val_mean_absolute_error: 0.4376
# Epoch 63/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2415 - mean_absolute_error: 0.3783 - val_loss: 0.3055 - val_mean_absolute_error: 0.4373
# Epoch 64/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2399 - mean_absolute_error: 0.3770 - val_loss: 0.3039 - val_mean_absolute_error: 0.4361
# Epoch 65/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2398 - mean_absolute_error: 0.3780 - val_loss: 0.3035 - val_mean_absolute_error: 0.4363
# Epoch 66/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2393 - mean_absolute_error: 0.3772 - val_loss: 0.3026 - val_mean_absolute_error: 0.4348
# Epoch 67/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2370 - mean_absolute_error: 0.3757 - val_loss: 0.3042 - val_mean_absolute_error: 0.4368
# Epoch 68/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2362 - mean_absolute_error: 0.3755 - val_loss: 0.3038 - val_mean_absolute_error: 0.4358
# Epoch 69/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2396 - mean_absolute_error: 0.3781 - val_loss: 0.3019 - val_mean_absolute_error: 0.4336
# Epoch 70/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2353 - mean_absolute_error: 0.3745 - val_loss: 0.3058 - val_mean_absolute_error: 0.4385
# Epoch 71/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2361 - mean_absolute_error: 0.3785 - val_loss: 0.2987 - val_mean_absolute_error: 0.4323
# Epoch 72/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2312 - mean_absolute_error: 0.3729 - val_loss: 0.2965 - val_mean_absolute_error: 0.4303
# Epoch 73/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2300 - mean_absolute_error: 0.3718 - val_loss: 0.2942 - val_mean_absolute_error: 0.4281
# Epoch 74/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2292 - mean_absolute_error: 0.3709 - val_loss: 0.2934 - val_mean_absolute_error: 0.4281
# Epoch 75/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2299 - mean_absolute_error: 0.3719 - val_loss: 0.2926 - val_mean_absolute_error: 0.4240
# Epoch 76/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2279 - mean_absolute_error: 0.3703 - val_loss: 0.2906 - val_mean_absolute_error: 0.4215
# Epoch 77/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2282 - mean_absolute_error: 0.3719 - val_loss: 0.2893 - val_mean_absolute_error: 0.4202
# Epoch 78/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2294 - mean_absolute_error: 0.3704 - val_loss: 0.2884 - val_mean_absolute_error: 0.4183
# Epoch 79/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2277 - mean_absolute_error: 0.3701 - val_loss: 0.2863 - val_mean_absolute_error: 0.4168
# Epoch 80/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2327 - mean_absolute_error: 0.3748 - val_loss: 0.2880 - val_mean_absolute_error: 0.4180
# Epoch 81/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2247 - mean_absolute_error: 0.3689 - val_loss: 0.2876 - val_mean_absolute_error: 0.4194
# Epoch 82/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2264 - mean_absolute_error: 0.3703 - val_loss: 0.2854 - val_mean_absolute_error: 0.4212
# Epoch 83/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2226 - mean_absolute_error: 0.3693 - val_loss: 0.2777 - val_mean_absolute_error: 0.4168
# Epoch 84/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2242 - mean_absolute_error: 0.3695 - val_loss: 0.2753 - val_mean_absolute_error: 0.4123
# Epoch 85/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2226 - mean_absolute_error: 0.3682 - val_loss: 0.2770 - val_mean_absolute_error: 0.4124
# Epoch 86/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2196 - mean_absolute_error: 0.3637 - val_loss: 0.2811 - val_mean_absolute_error: 0.4168
# Epoch 87/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2197 - mean_absolute_error: 0.3631 - val_loss: 0.2769 - val_mean_absolute_error: 0.4106
# Epoch 88/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2205 - mean_absolute_error: 0.3635 - val_loss: 0.2755 - val_mean_absolute_error: 0.4069
# Epoch 89/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2198 - mean_absolute_error: 0.3632 - val_loss: 0.2751 - val_mean_absolute_error: 0.4103
# Epoch 90/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2168 - mean_absolute_error: 0.3620 - val_loss: 0.2750 - val_mean_absolute_error: 0.4093
# Epoch 91/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2197 - mean_absolute_error: 0.3630 - val_loss: 0.2760 - val_mean_absolute_error: 0.4113
# Epoch 92/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2178 - mean_absolute_error: 0.3628 - val_loss: 0.2752 - val_mean_absolute_error: 0.4131
# Epoch 93/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2151 - mean_absolute_error: 0.3586 - val_loss: 0.2747 - val_mean_absolute_error: 0.4118
# Epoch 94/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2143 - mean_absolute_error: 0.3599 - val_loss: 0.2746 - val_mean_absolute_error: 0.4128
# Epoch 95/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2227 - mean_absolute_error: 0.3660 - val_loss: 0.2730 - val_mean_absolute_error: 0.4096
# Epoch 96/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2153 - mean_absolute_error: 0.3601 - val_loss: 0.2758 - val_mean_absolute_error: 0.4143
# Epoch 97/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2121 - mean_absolute_error: 0.3586 - val_loss: 0.2763 - val_mean_absolute_error: 0.4130
# Epoch 98/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2202 - mean_absolute_error: 0.3637 - val_loss: 0.2733 - val_mean_absolute_error: 0.4111
# Epoch 99/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2135 - mean_absolute_error: 0.3592 - val_loss: 0.2754 - val_mean_absolute_error: 0.4116
# Epoch 100/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2126 - mean_absolute_error: 0.3561 - val_loss: 0.2737 - val_mean_absolute_error: 0.4104
# Epoch 101/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2167 - mean_absolute_error: 0.3595 - val_loss: 0.2709 - val_mean_absolute_error: 0.4077
# Epoch 102/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2155 - mean_absolute_error: 0.3626 - val_loss: 0.2766 - val_mean_absolute_error: 0.4133
# Epoch 103/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2117 - mean_absolute_error: 0.3566 - val_loss: 0.2797 - val_mean_absolute_error: 0.4102
# Epoch 104/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2134 - mean_absolute_error: 0.3561 - val_loss: 0.2715 - val_mean_absolute_error: 0.4072
# Epoch 105/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2101 - mean_absolute_error: 0.3564 - val_loss: 0.2704 - val_mean_absolute_error: 0.4057
# Epoch 106/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2085 - mean_absolute_error: 0.3550 - val_loss: 0.2693 - val_mean_absolute_error: 0.4079
# Epoch 107/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2097 - mean_absolute_error: 0.3567 - val_loss: 0.2678 - val_mean_absolute_error: 0.4054
# Epoch 108/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2080 - mean_absolute_error: 0.3544 - val_loss: 0.2652 - val_mean_absolute_error: 0.4032
# Epoch 109/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2092 - mean_absolute_error: 0.3570 - val_loss: 0.2658 - val_mean_absolute_error: 0.4027
# Epoch 110/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2056 - mean_absolute_error: 0.3534 - val_loss: 0.2672 - val_mean_absolute_error: 0.4039
# Epoch 111/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2065 - mean_absolute_error: 0.3540 - val_loss: 0.2680 - val_mean_absolute_error: 0.4064
# Epoch 112/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2062 - mean_absolute_error: 0.3532 - val_loss: 0.2678 - val_mean_absolute_error: 0.4073
# Epoch 113/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2066 - mean_absolute_error: 0.3536 - val_loss: 0.2665 - val_mean_absolute_error: 0.4074
# Epoch 114/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2043 - mean_absolute_error: 0.3525 - val_loss: 0.2666 - val_mean_absolute_error: 0.4071
# Epoch 115/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2047 - mean_absolute_error: 0.3518 - val_loss: 0.2674 - val_mean_absolute_error: 0.4076
# Epoch 116/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2047 - mean_absolute_error: 0.3535 - val_loss: 0.2661 - val_mean_absolute_error: 0.4059
# Epoch 117/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2039 - mean_absolute_error: 0.3531 - val_loss: 0.2665 - val_mean_absolute_error: 0.4070
# Epoch 118/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2007 - mean_absolute_error: 0.3499 - val_loss: 0.2670 - val_mean_absolute_error: 0.4079
# Epoch 119/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2012 - mean_absolute_error: 0.3486 - val_loss: 0.2679 - val_mean_absolute_error: 0.4073
# Epoch 120/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2101 - mean_absolute_error: 0.3553 - val_loss: 0.2654 - val_mean_absolute_error: 0.4059
# Epoch 121/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2055 - mean_absolute_error: 0.3509 - val_loss: 0.2697 - val_mean_absolute_error: 0.4094
# Epoch 122/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2023 - mean_absolute_error: 0.3464 - val_loss: 0.2710 - val_mean_absolute_error: 0.4091
# Epoch 123/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1987 - mean_absolute_error: 0.3465 - val_loss: 0.2725 - val_mean_absolute_error: 0.4094
# Epoch 124/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2047 - mean_absolute_error: 0.3500 - val_loss: 0.2710 - val_mean_absolute_error: 0.4093
# Epoch 125/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2025 - mean_absolute_error: 0.3513 - val_loss: 0.2695 - val_mean_absolute_error: 0.4105
# Epoch 126/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2006 - mean_absolute_error: 0.3465 - val_loss: 0.2646 - val_mean_absolute_error: 0.4040
# Epoch 127/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1988 - mean_absolute_error: 0.3489 - val_loss: 0.2652 - val_mean_absolute_error: 0.4031
# Epoch 128/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1965 - mean_absolute_error: 0.3438 - val_loss: 0.2642 - val_mean_absolute_error: 0.4045
# Epoch 129/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1969 - mean_absolute_error: 0.3448 - val_loss: 0.2640 - val_mean_absolute_error: 0.4038
# Epoch 130/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2002 - mean_absolute_error: 0.3467 - val_loss: 0.2648 - val_mean_absolute_error: 0.4027
# Epoch 131/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1959 - mean_absolute_error: 0.3423 - val_loss: 0.2626 - val_mean_absolute_error: 0.3994
# Epoch 132/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1940 - mean_absolute_error: 0.3410 - val_loss: 0.2647 - val_mean_absolute_error: 0.4009
# Epoch 133/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1959 - mean_absolute_error: 0.3423 - val_loss: 0.2617 - val_mean_absolute_error: 0.4013
# Epoch 134/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1979 - mean_absolute_error: 0.3457 - val_loss: 0.2609 - val_mean_absolute_error: 0.4064
# Epoch 135/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1966 - mean_absolute_error: 0.3464 - val_loss: 0.2650 - val_mean_absolute_error: 0.4093
# Epoch 136/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1919 - mean_absolute_error: 0.3425 - val_loss: 0.2658 - val_mean_absolute_error: 0.4117
# Epoch 137/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1960 - mean_absolute_error: 0.3454 - val_loss: 0.2631 - val_mean_absolute_error: 0.4089
# Epoch 138/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1920 - mean_absolute_error: 0.3422 - val_loss: 0.2621 - val_mean_absolute_error: 0.4059
# Epoch 139/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1905 - mean_absolute_error: 0.3417 - val_loss: 0.2604 - val_mean_absolute_error: 0.4023
# Epoch 140/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1944 - mean_absolute_error: 0.3437 - val_loss: 0.2582 - val_mean_absolute_error: 0.4015
# Epoch 141/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1932 - mean_absolute_error: 0.3424 - val_loss: 0.2595 - val_mean_absolute_error: 0.4013
# Epoch 142/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1910 - mean_absolute_error: 0.3392 - val_loss: 0.2593 - val_mean_absolute_error: 0.4023
# Epoch 143/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1897 - mean_absolute_error: 0.3368 - val_loss: 0.2610 - val_mean_absolute_error: 0.4031
# Epoch 144/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1911 - mean_absolute_error: 0.3412 - val_loss: 0.2593 - val_mean_absolute_error: 0.4030
# Epoch 145/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1886 - mean_absolute_error: 0.3373 - val_loss: 0.2638 - val_mean_absolute_error: 0.4078
# Epoch 146/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1895 - mean_absolute_error: 0.3387 - val_loss: 0.2664 - val_mean_absolute_error: 0.4105
# Epoch 147/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1903 - mean_absolute_error: 0.3408 - val_loss: 0.2660 - val_mean_absolute_error: 0.4100
# Epoch 148/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1924 - mean_absolute_error: 0.3438 - val_loss: 0.2638 - val_mean_absolute_error: 0.4084
# Epoch 149/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1907 - mean_absolute_error: 0.3451 - val_loss: 0.2650 - val_mean_absolute_error: 0.4063
# Epoch 150/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1891 - mean_absolute_error: 0.3390 - val_loss: 0.2655 - val_mean_absolute_error: 0.4103

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# rmse :  0.5283716520796011   nrmse :  0.2616377807942085

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()
