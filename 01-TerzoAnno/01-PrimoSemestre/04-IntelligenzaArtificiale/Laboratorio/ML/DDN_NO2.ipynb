# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(40, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), alla activation functions should be ReLU.

# %%
def create_model_tiny(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(3, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small(input_size):
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium(input_size):
    # create model
    model = Sequential()    
    #your code here	
    model.add(Dense(10, input_dim = input_size, activation = "relu"))
    model.add(Dense(30, activation = "relu"))
    model.add(Dense(1))

    model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = [metrics.MeanAbsoluteError()])
    #your code here END
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matring among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
n_df = df.to_numpy() #n_df=n_df.values

#divide predictors from features
X = n_df[:, 1:]; # All features (cols from 2 to 8)
y = n_df[:, 0]; # Only predictors (col 1)

print("df shape ", n_df.shape)
print("X shape ", X.shape)
print("y shape ", y.shape)

seed = 7
np.random.seed(seed)

# split dataset in 77% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30, random_state = seed);#insert your code here

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_large(X_train.shape[1])
model.summary()
# Out:
# df shape  (500, 8)
# X shape  (500, 7)
# y shape  (500,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                80
#
#  dense_1 (Dense)             (None, 30)                330
#
#  dense_2 (Dense)             (None, 40)                1240
#
#  dense_3 (Dense)             (None, 1)                 41
#
# =================================================================
# Total params: 1,691
# Trainable params: 1,691
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 [==============================] - 1s 29ms/step - loss: 15.1210 - mean_absolute_error: 3.8073 - val_loss: 13.9957 - val_mean_absolute_error: 3.6633
# Epoch 2/150
# 9/9 [==============================] - 0s 6ms/step - loss: 13.2773 - mean_absolute_error: 3.5648 - val_loss: 12.4063 - val_mean_absolute_error: 3.4445
# Epoch 3/150
# 9/9 [==============================] - 0s 6ms/step - loss: 11.6219 - mean_absolute_error: 3.3270 - val_loss: 10.7999 - val_mean_absolute_error: 3.2053
# Epoch 4/150
# 9/9 [==============================] - 0s 5ms/step - loss: 9.8238 - mean_absolute_error: 3.0462 - val_loss: 8.9806 - val_mean_absolute_error: 2.9067
# Epoch 5/150
# 9/9 [==============================] - 0s 6ms/step - loss: 7.8288 - mean_absolute_error: 2.6880 - val_loss: 6.8817 - val_mean_absolute_error: 2.5112
# Epoch 6/150
# 9/9 [==============================] - 0s 5ms/step - loss: 5.6555 - mean_absolute_error: 2.2270 - val_loss: 4.6857 - val_mean_absolute_error: 2.0097
# Epoch 7/150
# 9/9 [==============================] - 0s 5ms/step - loss: 3.5556 - mean_absolute_error: 1.6765 - val_loss: 2.8013 - val_mean_absolute_error: 1.5037
# Epoch 8/150
# 9/9 [==============================] - 0s 6ms/step - loss: 2.1339 - mean_absolute_error: 1.2539 - val_loss: 1.7319 - val_mean_absolute_error: 1.1331
# Epoch 9/150
# 9/9 [==============================] - 0s 5ms/step - loss: 1.5331 - mean_absolute_error: 1.0435 - val_loss: 1.2912 - val_mean_absolute_error: 0.9429
# Epoch 10/150
# 9/9 [==============================] - 0s 5ms/step - loss: 1.2370 - mean_absolute_error: 0.9102 - val_loss: 0.9921 - val_mean_absolute_error: 0.8214
# Epoch 11/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.9598 - mean_absolute_error: 0.7983 - val_loss: 0.8054 - val_mean_absolute_error: 0.7318
# Epoch 12/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7758 - mean_absolute_error: 0.7206 - val_loss: 0.7008 - val_mean_absolute_error: 0.6681
# Epoch 13/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6821 - mean_absolute_error: 0.6644 - val_loss: 0.6158 - val_mean_absolute_error: 0.6179
# Epoch 14/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6162 - mean_absolute_error: 0.6302 - val_loss: 0.5708 - val_mean_absolute_error: 0.5929
# Epoch 15/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5683 - mean_absolute_error: 0.6016 - val_loss: 0.5346 - val_mean_absolute_error: 0.5706
# Epoch 16/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5325 - mean_absolute_error: 0.5798 - val_loss: 0.5006 - val_mean_absolute_error: 0.5478
# Epoch 17/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5046 - mean_absolute_error: 0.5619 - val_loss: 0.4770 - val_mean_absolute_error: 0.5315
# Epoch 18/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4756 - mean_absolute_error: 0.5427 - val_loss: 0.4576 - val_mean_absolute_error: 0.5176
# Epoch 19/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4543 - mean_absolute_error: 0.5296 - val_loss: 0.4381 - val_mean_absolute_error: 0.5011
# Epoch 20/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4337 - mean_absolute_error: 0.5196 - val_loss: 0.4273 - val_mean_absolute_error: 0.4942
# Epoch 21/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4171 - mean_absolute_error: 0.5106 - val_loss: 0.4158 - val_mean_absolute_error: 0.4843
# Epoch 22/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4029 - mean_absolute_error: 0.4997 - val_loss: 0.4063 - val_mean_absolute_error: 0.4769
# Epoch 23/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3918 - mean_absolute_error: 0.4917 - val_loss: 0.4001 - val_mean_absolute_error: 0.4725
# Epoch 24/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3805 - mean_absolute_error: 0.4841 - val_loss: 0.3946 - val_mean_absolute_error: 0.4693
# Epoch 25/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3713 - mean_absolute_error: 0.4760 - val_loss: 0.3857 - val_mean_absolute_error: 0.4639
# Epoch 26/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3648 - mean_absolute_error: 0.4694 - val_loss: 0.3803 - val_mean_absolute_error: 0.4604
# Epoch 27/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3573 - mean_absolute_error: 0.4634 - val_loss: 0.3761 - val_mean_absolute_error: 0.4579
# Epoch 28/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3493 - mean_absolute_error: 0.4586 - val_loss: 0.3731 - val_mean_absolute_error: 0.4555
# Epoch 29/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3457 - mean_absolute_error: 0.4546 - val_loss: 0.3686 - val_mean_absolute_error: 0.4536
# Epoch 30/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3390 - mean_absolute_error: 0.4511 - val_loss: 0.3706 - val_mean_absolute_error: 0.4584
# Epoch 31/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3346 - mean_absolute_error: 0.4492 - val_loss: 0.3655 - val_mean_absolute_error: 0.4556
# Epoch 32/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3306 - mean_absolute_error: 0.4460 - val_loss: 0.3594 - val_mean_absolute_error: 0.4543
# Epoch 33/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3249 - mean_absolute_error: 0.4420 - val_loss: 0.3567 - val_mean_absolute_error: 0.4521
# Epoch 34/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3214 - mean_absolute_error: 0.4396 - val_loss: 0.3529 - val_mean_absolute_error: 0.4495
# Epoch 35/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3168 - mean_absolute_error: 0.4350 - val_loss: 0.3512 - val_mean_absolute_error: 0.4473
# Epoch 36/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3149 - mean_absolute_error: 0.4337 - val_loss: 0.3495 - val_mean_absolute_error: 0.4448
# Epoch 37/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3094 - mean_absolute_error: 0.4261 - val_loss: 0.3480 - val_mean_absolute_error: 0.4445
# Epoch 38/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3079 - mean_absolute_error: 0.4251 - val_loss: 0.3453 - val_mean_absolute_error: 0.4417
# Epoch 39/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3038 - mean_absolute_error: 0.4231 - val_loss: 0.3431 - val_mean_absolute_error: 0.4394
# Epoch 40/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3022 - mean_absolute_error: 0.4242 - val_loss: 0.3444 - val_mean_absolute_error: 0.4412
# Epoch 41/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3012 - mean_absolute_error: 0.4257 - val_loss: 0.3405 - val_mean_absolute_error: 0.4400
# Epoch 42/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2944 - mean_absolute_error: 0.4150 - val_loss: 0.3401 - val_mean_absolute_error: 0.4430
# Epoch 43/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2995 - mean_absolute_error: 0.4227 - val_loss: 0.3367 - val_mean_absolute_error: 0.4376
# Epoch 44/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2904 - mean_absolute_error: 0.4125 - val_loss: 0.3338 - val_mean_absolute_error: 0.4359
# Epoch 45/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2906 - mean_absolute_error: 0.4109 - val_loss: 0.3326 - val_mean_absolute_error: 0.4343
# Epoch 46/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2864 - mean_absolute_error: 0.4080 - val_loss: 0.3320 - val_mean_absolute_error: 0.4333
# Epoch 47/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2849 - mean_absolute_error: 0.4081 - val_loss: 0.3315 - val_mean_absolute_error: 0.4329
# Epoch 48/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2834 - mean_absolute_error: 0.4051 - val_loss: 0.3299 - val_mean_absolute_error: 0.4331
# Epoch 49/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2814 - mean_absolute_error: 0.4036 - val_loss: 0.3292 - val_mean_absolute_error: 0.4313
# Epoch 50/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2787 - mean_absolute_error: 0.4042 - val_loss: 0.3281 - val_mean_absolute_error: 0.4307
# Epoch 51/150
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2777 - mean_absolute_error: 0.4005 - val_loss: 0.3274 - val_mean_absolute_error: 0.4319
# Epoch 52/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2748 - mean_absolute_error: 0.3999 - val_loss: 0.3273 - val_mean_absolute_error: 0.4316
# Epoch 53/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2750 - mean_absolute_error: 0.4037 - val_loss: 0.3296 - val_mean_absolute_error: 0.4328
# Epoch 54/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2720 - mean_absolute_error: 0.4007 - val_loss: 0.3259 - val_mean_absolute_error: 0.4329
# Epoch 55/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2703 - mean_absolute_error: 0.3971 - val_loss: 0.3251 - val_mean_absolute_error: 0.4333
# Epoch 56/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2685 - mean_absolute_error: 0.3962 - val_loss: 0.3232 - val_mean_absolute_error: 0.4297
# Epoch 57/150
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2676 - mean_absolute_error: 0.3963 - val_loss: 0.3239 - val_mean_absolute_error: 0.4288
# Epoch 58/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2680 - mean_absolute_error: 0.3970 - val_loss: 0.3247 - val_mean_absolute_error: 0.4301
# Epoch 59/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2649 - mean_absolute_error: 0.3938 - val_loss: 0.3230 - val_mean_absolute_error: 0.4323
# Epoch 60/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2653 - mean_absolute_error: 0.3969 - val_loss: 0.3256 - val_mean_absolute_error: 0.4344
# Epoch 61/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2645 - mean_absolute_error: 0.3963 - val_loss: 0.3221 - val_mean_absolute_error: 0.4314
# Epoch 62/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2598 - mean_absolute_error: 0.3909 - val_loss: 0.3203 - val_mean_absolute_error: 0.4291
# Epoch 63/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2584 - mean_absolute_error: 0.3897 - val_loss: 0.3194 - val_mean_absolute_error: 0.4301
# Epoch 64/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2621 - mean_absolute_error: 0.3903 - val_loss: 0.3212 - val_mean_absolute_error: 0.4331
# Epoch 65/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2557 - mean_absolute_error: 0.3850 - val_loss: 0.3197 - val_mean_absolute_error: 0.4283
# Epoch 66/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2596 - mean_absolute_error: 0.3949 - val_loss: 0.3166 - val_mean_absolute_error: 0.4250
# Epoch 67/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2533 - mean_absolute_error: 0.3857 - val_loss: 0.3155 - val_mean_absolute_error: 0.4284
# Epoch 68/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2542 - mean_absolute_error: 0.3841 - val_loss: 0.3158 - val_mean_absolute_error: 0.4290
# Epoch 69/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2515 - mean_absolute_error: 0.3822 - val_loss: 0.3149 - val_mean_absolute_error: 0.4261
# Epoch 70/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2532 - mean_absolute_error: 0.3893 - val_loss: 0.3160 - val_mean_absolute_error: 0.4264
# Epoch 71/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2625 - mean_absolute_error: 0.3892 - val_loss: 0.3236 - val_mean_absolute_error: 0.4354
# Epoch 72/150
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2437 - mean_absolute_error: 0.3761 - val_loss: 0.3255 - val_mean_absolute_error: 0.4343
# Epoch 73/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2567 - mean_absolute_error: 0.3960 - val_loss: 0.3164 - val_mean_absolute_error: 0.4290
# Epoch 74/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2517 - mean_absolute_error: 0.3813 - val_loss: 0.3214 - val_mean_absolute_error: 0.4354
# Epoch 75/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2473 - mean_absolute_error: 0.3788 - val_loss: 0.3134 - val_mean_absolute_error: 0.4247
# Epoch 76/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2500 - mean_absolute_error: 0.3872 - val_loss: 0.3139 - val_mean_absolute_error: 0.4231
# Epoch 77/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2437 - mean_absolute_error: 0.3778 - val_loss: 0.3126 - val_mean_absolute_error: 0.4267
# Epoch 78/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2449 - mean_absolute_error: 0.3764 - val_loss: 0.3130 - val_mean_absolute_error: 0.4285
# Epoch 79/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2424 - mean_absolute_error: 0.3762 - val_loss: 0.3117 - val_mean_absolute_error: 0.4261
# Epoch 80/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2411 - mean_absolute_error: 0.3753 - val_loss: 0.3113 - val_mean_absolute_error: 0.4236
# Epoch 81/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2405 - mean_absolute_error: 0.3745 - val_loss: 0.3114 - val_mean_absolute_error: 0.4223
# Epoch 82/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2407 - mean_absolute_error: 0.3771 - val_loss: 0.3119 - val_mean_absolute_error: 0.4242
# Epoch 83/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2383 - mean_absolute_error: 0.3711 - val_loss: 0.3141 - val_mean_absolute_error: 0.4281
# Epoch 84/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2389 - mean_absolute_error: 0.3717 - val_loss: 0.3134 - val_mean_absolute_error: 0.4250
# Epoch 85/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2361 - mean_absolute_error: 0.3720 - val_loss: 0.3170 - val_mean_absolute_error: 0.4307
# Epoch 86/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2394 - mean_absolute_error: 0.3739 - val_loss: 0.3176 - val_mean_absolute_error: 0.4341
# Epoch 87/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2403 - mean_absolute_error: 0.3788 - val_loss: 0.3172 - val_mean_absolute_error: 0.4335
# Epoch 88/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2406 - mean_absolute_error: 0.3784 - val_loss: 0.3201 - val_mean_absolute_error: 0.4351
# Epoch 89/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2364 - mean_absolute_error: 0.3717 - val_loss: 0.3166 - val_mean_absolute_error: 0.4279
# Epoch 90/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2342 - mean_absolute_error: 0.3728 - val_loss: 0.3178 - val_mean_absolute_error: 0.4271
# Epoch 91/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2319 - mean_absolute_error: 0.3696 - val_loss: 0.3164 - val_mean_absolute_error: 0.4298
# Epoch 92/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2316 - mean_absolute_error: 0.3682 - val_loss: 0.3167 - val_mean_absolute_error: 0.4305
# Epoch 93/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2300 - mean_absolute_error: 0.3690 - val_loss: 0.3191 - val_mean_absolute_error: 0.4316
# Epoch 94/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2311 - mean_absolute_error: 0.3722 - val_loss: 0.3200 - val_mean_absolute_error: 0.4328
# Epoch 95/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2301 - mean_absolute_error: 0.3710 - val_loss: 0.3209 - val_mean_absolute_error: 0.4351
# Epoch 96/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2332 - mean_absolute_error: 0.3720 - val_loss: 0.3250 - val_mean_absolute_error: 0.4403
# Epoch 97/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2319 - mean_absolute_error: 0.3755 - val_loss: 0.3224 - val_mean_absolute_error: 0.4338
# Epoch 98/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2289 - mean_absolute_error: 0.3724 - val_loss: 0.3210 - val_mean_absolute_error: 0.4360
# Epoch 99/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2348 - mean_absolute_error: 0.3708 - val_loss: 0.3325 - val_mean_absolute_error: 0.4461
# Epoch 100/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2269 - mean_absolute_error: 0.3674 - val_loss: 0.3210 - val_mean_absolute_error: 0.4357
# Epoch 101/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2260 - mean_absolute_error: 0.3692 - val_loss: 0.3189 - val_mean_absolute_error: 0.4354
# Epoch 102/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2231 - mean_absolute_error: 0.3647 - val_loss: 0.3205 - val_mean_absolute_error: 0.4358
# Epoch 103/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2232 - mean_absolute_error: 0.3610 - val_loss: 0.3185 - val_mean_absolute_error: 0.4327
# Epoch 104/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2228 - mean_absolute_error: 0.3647 - val_loss: 0.3226 - val_mean_absolute_error: 0.4339
# Epoch 105/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2229 - mean_absolute_error: 0.3645 - val_loss: 0.3196 - val_mean_absolute_error: 0.4354
# Epoch 106/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2222 - mean_absolute_error: 0.3640 - val_loss: 0.3189 - val_mean_absolute_error: 0.4398
# Epoch 107/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2234 - mean_absolute_error: 0.3631 - val_loss: 0.3274 - val_mean_absolute_error: 0.4469
# Epoch 108/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2201 - mean_absolute_error: 0.3608 - val_loss: 0.3228 - val_mean_absolute_error: 0.4395
# Epoch 109/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2213 - mean_absolute_error: 0.3672 - val_loss: 0.3227 - val_mean_absolute_error: 0.4373
# Epoch 110/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2161 - mean_absolute_error: 0.3576 - val_loss: 0.3215 - val_mean_absolute_error: 0.4388
# Epoch 111/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2179 - mean_absolute_error: 0.3574 - val_loss: 0.3206 - val_mean_absolute_error: 0.4375
# Epoch 112/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2175 - mean_absolute_error: 0.3597 - val_loss: 0.3215 - val_mean_absolute_error: 0.4370
# Epoch 113/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2155 - mean_absolute_error: 0.3590 - val_loss: 0.3237 - val_mean_absolute_error: 0.4388
# Epoch 114/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2153 - mean_absolute_error: 0.3566 - val_loss: 0.3261 - val_mean_absolute_error: 0.4400
# Epoch 115/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2157 - mean_absolute_error: 0.3568 - val_loss: 0.3252 - val_mean_absolute_error: 0.4403
# Epoch 116/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2127 - mean_absolute_error: 0.3554 - val_loss: 0.3261 - val_mean_absolute_error: 0.4415
# Epoch 117/150
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2130 - mean_absolute_error: 0.3556 - val_loss: 0.3269 - val_mean_absolute_error: 0.4422
# Epoch 118/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2127 - mean_absolute_error: 0.3550 - val_loss: 0.3255 - val_mean_absolute_error: 0.4406
# Epoch 119/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2131 - mean_absolute_error: 0.3584 - val_loss: 0.3253 - val_mean_absolute_error: 0.4388
# Epoch 120/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2116 - mean_absolute_error: 0.3534 - val_loss: 0.3300 - val_mean_absolute_error: 0.4448
# Epoch 121/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2148 - mean_absolute_error: 0.3575 - val_loss: 0.3253 - val_mean_absolute_error: 0.4415
# Epoch 122/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2102 - mean_absolute_error: 0.3545 - val_loss: 0.3253 - val_mean_absolute_error: 0.4429
# Epoch 123/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2138 - mean_absolute_error: 0.3562 - val_loss: 0.3231 - val_mean_absolute_error: 0.4409
# Epoch 124/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2147 - mean_absolute_error: 0.3618 - val_loss: 0.3235 - val_mean_absolute_error: 0.4384
# Epoch 125/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2130 - mean_absolute_error: 0.3557 - val_loss: 0.3237 - val_mean_absolute_error: 0.4411
# Epoch 126/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2081 - mean_absolute_error: 0.3544 - val_loss: 0.3255 - val_mean_absolute_error: 0.4414
# Epoch 127/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2089 - mean_absolute_error: 0.3517 - val_loss: 0.3241 - val_mean_absolute_error: 0.4407
# Epoch 128/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2113 - mean_absolute_error: 0.3518 - val_loss: 0.3204 - val_mean_absolute_error: 0.4363
# Epoch 129/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2128 - mean_absolute_error: 0.3595 - val_loss: 0.3226 - val_mean_absolute_error: 0.4371
# Epoch 130/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2175 - mean_absolute_error: 0.3556 - val_loss: 0.3285 - val_mean_absolute_error: 0.4427
# Epoch 131/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2127 - mean_absolute_error: 0.3581 - val_loss: 0.3252 - val_mean_absolute_error: 0.4353
# Epoch 132/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2078 - mean_absolute_error: 0.3506 - val_loss: 0.3268 - val_mean_absolute_error: 0.4434
# Epoch 133/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2038 - mean_absolute_error: 0.3458 - val_loss: 0.3230 - val_mean_absolute_error: 0.4398
# Epoch 134/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2055 - mean_absolute_error: 0.3530 - val_loss: 0.3228 - val_mean_absolute_error: 0.4412
# Epoch 135/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2029 - mean_absolute_error: 0.3478 - val_loss: 0.3249 - val_mean_absolute_error: 0.4455
# Epoch 136/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2017 - mean_absolute_error: 0.3446 - val_loss: 0.3207 - val_mean_absolute_error: 0.4409
# Epoch 137/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2007 - mean_absolute_error: 0.3466 - val_loss: 0.3207 - val_mean_absolute_error: 0.4376
# Epoch 138/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2037 - mean_absolute_error: 0.3505 - val_loss: 0.3226 - val_mean_absolute_error: 0.4365
# Epoch 139/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2025 - mean_absolute_error: 0.3487 - val_loss: 0.3224 - val_mean_absolute_error: 0.4358
# Epoch 140/150
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2005 - mean_absolute_error: 0.3465 - val_loss: 0.3231 - val_mean_absolute_error: 0.4429
# Epoch 141/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2011 - mean_absolute_error: 0.3453 - val_loss: 0.3206 - val_mean_absolute_error: 0.4360
# Epoch 142/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1985 - mean_absolute_error: 0.3431 - val_loss: 0.3211 - val_mean_absolute_error: 0.4317
# Epoch 143/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1996 - mean_absolute_error: 0.3458 - val_loss: 0.3190 - val_mean_absolute_error: 0.4319
# Epoch 144/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1969 - mean_absolute_error: 0.3444 - val_loss: 0.3222 - val_mean_absolute_error: 0.4373
# Epoch 145/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1966 - mean_absolute_error: 0.3437 - val_loss: 0.3237 - val_mean_absolute_error: 0.4372
# Epoch 146/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1986 - mean_absolute_error: 0.3481 - val_loss: 0.3248 - val_mean_absolute_error: 0.4405
# Epoch 147/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2001 - mean_absolute_error: 0.3467 - val_loss: 0.3192 - val_mean_absolute_error: 0.4397
# Epoch 148/150
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1958 - mean_absolute_error: 0.3428 - val_loss: 0.3194 - val_mean_absolute_error: 0.4373
# Epoch 149/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1933 - mean_absolute_error: 0.3402 - val_loss: 0.3246 - val_mean_absolute_error: 0.4419
# Epoch 150/150
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1947 - mean_absolute_error: 0.3423 - val_loss: 0.3237 - val_mean_absolute_error: 0.4401

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 [==============================] - 0s 1ms/step
# rmse :  0.5608136458311275   nrmse :  0.2777023278157625

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()
